# %%
import pandas as pd
import numpy as np

# %%
trump=pd.read_csv(r'C:\Users\BorisGrinberg\Dropbox\PC (2)\Desktop\David\trump engagement.csv')

# %%
trump.columns
# Out:
# Index(['created_at', 'text', 'user_screen_name', 'user_created_at',
#        'favorite_count', 'user_followers_count', 'user_friends_count',
#        'is_quote', 'retweeted', 'retweet_count', 'user_id_str',
#        'user_verified', 'user_description', 'user_name', 'lang', 'reply_count',
#        'quote_count', 'neg', 'neu', 'pos', 'compound'],
#       dtype='object')

# %%
trump.head()
# Out:
#    created_at                                               text  \
# 0  2020-09-01  Anyone else notice that Trump supporters have ...
# 1  2020-09-01   First #TheCorruptPartyOfTrump #LootingDecency...
# 2  2020-09-01  Can we take the gloves off and tell the truth?...
# 3  2020-09-01  @Timcast @realDonaldTrump @DonaldJTrumpJr so n...
# 4  2020-09-01  Anatomy of a Trump smear:  Trump makes a false...
#
#   user_screen_name                 user_created_at  favorite_count  \
# 0          cathymv  Mon Dec 08 16:00:12 +0000 2008               0
# 1         waybeyon  Sat May 01 01:59:07 +0000 2010               0
# 2         byronesk  Tue Aug 16 21:17:49 +0000 2011               0
# 3   michaelosas346  Sat Sep 09 14:46:28 +0000 2017               0
# 4        celephane  Thu Mar 03 09:22:09 +0000 2016               0
#
#    user_followers_count  user_friends_count  is_quote  retweeted  \
# 0                  6931                7519         0          0
# ...

# %%
trump=trump.loc[:,['created_at', 'user_screen_name', 'is_quote', 'retweeted','user_followers_count', 'user_friends_count', 'compound']]

# %%
trump['user_followers_count'].mean()
# Out:
# 6240.777120333418

# %%
trump['user_friends_count'].mean()
# Out:
# 3117.015422312016

# %%
temp_list=[]
n_value=[]
compound_list=trump['compound'].to_list()
followers_list=trump['user_followers_count'].to_list()
following_list=trump['user_friends_count'].to_list()
i=0
while i<len(followers_list):
    temp=(followers_list[i])-(following_list[i])

    if temp>=10:
        a=np.log10(temp)
    else:
        a=1
    
    b=float(compound_list[i])
    temp_list.append((a*b))
    n_value.append(a)

    i=i+1

# %%
trump.head()
# Out:
#    created_at user_screen_name  is_quote  retweeted  user_followers_count  \
# 0  2020-09-01          cathymv         0          0                  6931
# 1  2020-09-01         waybeyon         1          0                  2140
# 2  2020-09-01         byronesk         0          0                  2907
# 3  2020-09-01   michaelosas346         1          0                   236
# 4  2020-09-01        celephane         0          0                  1751
#
#    user_friends_count  compound
# 0                7519    0.7964
# 1                2004    0.4019
# 2                5001   -0.9169
# 3                 803    0.0000
# 4                2226   -0.8225

# %%
trump['follower_multiplier']=n_value

# %%
trump['follower_multiplier_2']=[i-1 for i in n_value]
trump.head()
# Out:
#    created_at user_screen_name  is_quote  retweeted  user_followers_count  \
# 0  2020-09-01          cathymv         0          0                  6931
# 1  2020-09-01         waybeyon         1          0                  2140
# 2  2020-09-01         byronesk         0          0                  2907
# 3  2020-09-01   michaelosas346         1          0                   236
# 4  2020-09-01        celephane         0          0                  1751
#
#    user_friends_count  compound  follower_multiplier  follower_multiplier_2
# 0                7519    0.7964             1.000000               0.000000
# 1                2004    0.4019             2.133539               1.133539
# 2                5001   -0.9169             1.000000               0.000000
# 3                 803    0.0000             1.000000               0.000000
# 4                2226   -0.8225             1.000000               0.000000

# %%
trump['follower_multiplier'].mean()
# Out:
# 1.3409094394267251

# %%
i=0
sentiment_value_1_list=[]
sentiment_value_2_list=[]
while i<len(n_value):
    sentiment_value_1_list.append(compound_list[i] * n_value[i])
    sentiment_value_2_list.append(compound_list[i] * ((n_value[i])-1))
    
    
    i=i+1

trump['sentiment_value_1']=sentiment_value_1_list
trump['sentiment_value_2']=sentiment_value_2_list

# %%
trump['created_at']=pd.to_datetime(trump['created_at'])



date_list=list(set(trump['created_at']))
date_list.sort()

# %%
trump.set_index('created_at',inplace=True)

# %%
date_list[:-25]
# Out:
# [Timestamp('2020-09-01 00:00:00'),
#  Timestamp('2020-09-02 00:00:00'),
#  Timestamp('2020-09-03 00:00:00'),
#  Timestamp('2020-09-04 00:00:00'),
#  Timestamp('2020-09-05 00:00:00'),
#  Timestamp('2020-09-06 00:00:00'),
#  Timestamp('2020-09-07 00:00:00'),
#  Timestamp('2020-09-08 00:00:00'),
#  Timestamp('2020-09-09 00:00:00'),
#  Timestamp('2020-09-10 00:00:00'),
#  Timestamp('2020-09-11 00:00:00'),
#  Timestamp('2020-09-12 00:00:00'),
#  Timestamp('2020-09-13 00:00:00'),
#  Timestamp('2020-09-14 00:00:00'),
#  Timestamp('2020-09-15 00:00:00'),
#  Timestamp('2020-09-16 00:00:00'),
#  Timestamp('2020-09-17 00:00:00'),
#  Timestamp('2020-09-18 00:00:00'),
#  Timestamp('2020-09-19 00:00:00'),
#  Timestamp('2020-09-20 00:00:00'),
#  Timestamp('2020-09-21 00:00:00'),
#  Timestamp('2020-09-22 00:00:00'),
#  Timestamp('2020-09-23 00:00:00'),
#  Timestamp('2020-09-24 00:00:00'),
#  Timestamp('2020-09-25 00:00:00'),
#  Timestamp('2020-09-26 00:00:00'),
#  Timestamp('2020-09-27 00:00:00'),
# ...

# %%
trump=trump.loc[:'2020-11-03']
date_list=date_list[:-25]
#making stuff into list
trump_daily_sentiment_value_1=[]
trump_daily_sentiment_value_2=[]
for i in date_list:
    trump_daily_sentiment_value_1.append(trump.loc[i]['sentiment_value_1'].mean())
    trump_daily_sentiment_value_2.append(trump.loc[i]['sentiment_value_2'].mean())

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# prepping stuff for graphs 
JBPoll = mpatches.Patch(color='blue', label='Joe Biden Polls')
DTPoll = mpatches.Patch(color='red', label='Donald Trump Polls')
DTWPoll = mpatches.Patch(color='green', label='Trump Weighted Polling average')
JBWPoll = mpatches.Patch(color='magenta', label='Biden Weighted Polling average')
DiffPoll=mpatches.Patch(color='black', label='% difference between Biden & Trump')
yticks=[-.15,-.1,-.05,0,.05,.1]
grid_alpha=.5

# %%
fig,ax=plt.subplots(1,1,figsize=(20,14))

ax.plot(date_list,trump_daily_sentiment_value_1,label='trump_daily_sentiment_value_1',c="firebrick")
ax.plot(date_list,trump_daily_sentiment_value_2,label='trump_daily_sentiment_value_2',c="cornflowerblue")

ax.set_yticks(yticks)

ax.set_xlabel("Date")
ax.set_ylabel("Sentiment Analysis result")
ax.axhline(-.15, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.10, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(0, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.10, color='black',ls='--',alpha=grid_alpha)

ax.legend()
plt.show()

# %%
 T_daily_VADER=[]
for i in date_list:
    T_daily_VADER.append(trump.loc[i]['compound'].mean())

# %%
type(trump_daily_sentiment_value_1[1])
# Out:
# float

# %%
fig,ax=plt.subplots(1,1,figsize=(20,14))

ax.plot(date_list,trump_daily_sentiment_value_1,label='trump daily sentiment value',c="cornflowerblue")
ax.plot(date_list,T_daily_VADER,label='trump daily sentiment value - WEIGHTED',c="crimson")


ax.fill_between(date_list,trump_daily_sentiment_value_1,T_daily_VADER,
                where=(trump_daily_sentiment_value_1[i]>T_daily_VADER[i]),
                interpolate=True, 
                color="cornflowerblue")


#ax.fill_between(date_list,T_daily_VADER,trump_daily_sentiment_value_1,
                #where=(trump_daily_sentiment_value_1>T_daily_VADER),interpolate=True, color="crimson")

ax.set_yticks(yticks)

ax.set_xlabel("Date")
ax.set_ylabel("Sentiment Analysis result")
ax.axhline(-.15, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.10, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(0, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.10, color='black',ls='--',alpha=grid_alpha)

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [140], in <cell line: 7>()
#       3 ax.plot(date_list,trump_daily_sentiment_value_1,label='trump daily sentiment value',c="cornflowerblue")
#       4 ax.plot(date_list,T_daily_VADER,label='trump daily sentiment value - WEIGHTED',c="crimson")
#       7 ax.fill_between(date_list,trump_daily_sentiment_value_1,T_daily_VADER,
# ----> 8                 where=(trump_daily_sentiment_value_1[i]>T_daily_VADER[i]),
#       9                 interpolate=True,
#      10                 color="cornflowerblue")
#      13 #ax.fill_between(date_list,T_daily_VADER,trump_daily_sentiment_value_1,
#      14                 #where=(trump_daily_sentiment_value_1>T_daily_VADER),interpolate=True, color="crimson")
#      16 ax.set_yticks(yticks)
#
# TypeError: list indices must be integers or slices, not Timestamp

# %%
fig,ax=plt.subplots(1,1,figsize=(20,14))

ax.plot(date_list,trump_daily_sentiment_value_1,label='trump daily sentiment value',c="cornflowerblue")
ax.plot(date_list,T_daily_VADER,label='trump daily sentiment value - WEIGHTED',c="crimson")
ax.fill_between(date_list,trump_daily_sentiment_value_1,T_daily_VADER,interpolate=False, color="cornflowerblue")
ax.fill_between(date_list,T_daily_VADER,trump_daily_sentiment_value_1,interpolate=False, color="crimson")

ax.set_yticks(yticks)

ax.set_xlabel("Date")
ax.set_ylabel("Sentiment Analysis result")
ax.axhline(-.15, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.10, color='black',ls='--',alpha=grid_alpha)
ax.axhline(-.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(0, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.05, color='black',ls='--',alpha=grid_alpha)
ax.axhline(.10, color='black',ls='--',alpha=grid_alpha)

ax.legend()
plt.show()
