# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_t=pd.read_csv('D:/Final Project Econ/trump sentiment and tweets.csv')
df_b=pd.read_csv('D:/Final Project Econ/biden sentiment and tweets.csv')

# %%
df_t.head()
# Out:
#    created_at                                               text  \
# 0  2020-09-01  Anyone else notice that Trump supporters have ...
# 1  2020-09-01   First #TheCorruptPartyOfTrump #LootingDecency...
# 2  2020-09-01  Can we take the gloves off and tell the truth?...
# 3  2020-09-01  @Timcast @realDonaldTrump @DonaldJTrumpJr so n...
# 4  2020-09-01  Anatomy of a Trump smear:  Trump makes a false...
#
#   user_screen_name                 user_created_at  user_followers_count  \
# 0          cathymv  Mon Dec 08 16:00:12 +0000 2008                  6931
# 1         waybeyon  Sat May 01 01:59:07 +0000 2010                  2140
# 2         byronesk  Tue Aug 16 21:17:49 +0000 2011                  2907
# 3   michaelosas346  Sat Sep 09 14:46:28 +0000 2017                   236
# 4        celephane  Thu Mar 03 09:22:09 +0000 2016                  1751
#
#    user_friends_count  is_quote         user_id_str  user_verified  \
# 0                7519         0            17965226              0
# 1                2004         1           138930681              0
# 2                5001         0           356438982              0
# 3                 803         1  906529242120421376              0
# 4                2226         0  705322358890860545              0
#
#                                     user_description  \
# 0  Conservative NY'er- what can go wrong?NASCAR f...
# 1  Tweet together* help find & share our current ...
# 2  Conspirator, schizophrenic, co-conspirator. Sc...
# 3                                    BetterDaysAhead
# 4  Actress, Musician & Songwriter, Court Clerk 8t...
#
#                       user_name    neg    neu    pos  compound
# 0  Cathymv - #MAGA #CULT45 #KAG  0.000  0.701  0.299    0.7964
# 1                         wayne  0.000  0.895  0.105    0.4019
# 2                 John Stoddart  0.268  0.654  0.078   -0.9169
# 3                  Wendy fields  0.000  1.000  0.000    0.0000
# 4           Georgie.    #Resist  0.216  0.734  0.050   -0.8225

# %%
day_of_week_t=pd.to_datetime(df_t['created_at'])
day_of_week_t=day_of_week_t.dt.dayofweek.to_list()
df_t['day']=day_of_week_t

week=pd.to_datetime(df_t['created_at']).dt.isocalendar()
df_t['week']=week['week']

# %%
day_of_week_b=pd.to_datetime(df_b['created_at'])
day_of_week_b=day_of_week_b.dt.dayofweek.to_list()
df_b['day']=day_of_week_b

week_b=pd.to_datetime(df_b['created_at']).dt.isocalendar()
df_b['week']=week_b['week']

# %%
df_t.tail()
# Out:
#          created_at                                               text  \
# 3862324  2020-11-28  #Packers History: 9/13/2009    Aaron Rodgers t...
# 3862325  2020-11-28  @KlasfeldReports why is @MikeKellyPA so hellbe...
# 3862326  2020-11-28  @notcapnamerica They should start using the Go...
# 3862327  2020-11-28  Trump was in a frenzy to finalize his bird-kil...
# 3862328  2020-11-28  @CB618444 @realDonaldTrump If you are fully su...
#
#         user_screen_name                 user_created_at  \
# 3862324    BookOfEli_NFL  Mon Jan 01 19:58:34 +0000 2018
# 3862325   VAButlerwrites  Tue Jan 03 04:28:32 +0000 2017
# 3862326      Patta47cake  Wed Apr 29 11:57:04 +0000 2015
# 3862327       greggo1685  Wed Jun 13 20:40:13 +0000 2012
# 3862328  irishtravelerAZ  Thu Oct 15 23:12:15 +0000 2020
#
#          user_followers_count  user_friends_count  is_quote  \
# 3862324                  5493                 878         0
# 3862325                   598                 184         0
# 3862326                  7700                3986         0
# 3862327                  1128                1362         1
# 3862328                   381                1006         0
#
#                  user_id_str  user_verified  \
# 3862324   947920001448726528              0
# 3862325   816139154899668993              0
# 3862326           3179207340              0
# 3862327            607614048              0
# 3862328  1316879490694393857              0
#
#                                           user_description        user_name  \
# 3862324  Creator and host of @AMAFantasy    Co-host on ...    Eli Berkovits
# 3862325  Author/editor; books on Iraq & Sudan; reports ...  Victoria Butler
# 3862326  MomNew York Mets , Arsenal, Barcelona, New Yor...     PatsyDryden
# 3862327                                                 \N       G.Lombardi
# 3862328  Christian evangelist pro-lifepatriot MAGAtrave...         johnnieB
#
#            neg    neu    pos  compound  day  week
# 3862324  0.000  0.933  0.067    0.1280    5    48
# 3862325  0.000  1.000  0.000    0.0000    5    48
# 3862326  0.244  0.756  0.000   -0.8750    5    48
# 3862327  0.064  0.891  0.045   -0.2003    5    48
# 3862328  0.000  0.802  0.198    0.6901    5    48

# %%
df_t.set_index(['week','day'],inplace=True)
df_t.sort_index(inplace=True)

# %%
df_b.set_index(['week','day'],inplace=True)
df_b.sort_index(inplace=True)

# %%
df_t.loc[37]
# Out:
#      created_at                                               text  \
# day
# 0    2020-09-07  @shelby60235316 @Defenses09 good to know that ...
# 0    2020-09-07  I am so TIRED of people saying Trump is a whit...
# 0    2020-09-07  @gtconway3d      1 relax &amp; set'em @ ease w...
# 0    2020-09-07  Opinion | Trump flies to Kenosha but lands on ...
# 0    2020-09-07  High turnout by Trumps base wont be enough to ...
# ..          ...                                                ...
# 6    2020-09-13  @StephenKing @SandiAnthony1 Facts don't mean a...
# 6    2020-09-13  @MeidasTouch @RepTimRyan 194,000 Americans dea...
# 6    2020-09-13  @thehill This is some bullshit biased reportin...
# 6    2020-09-13  @RexChapman @donwinslow Trump administration d...
# 6    2020-09-13  @Tiffluvs2shop @ReaganBabe it wasn't trump who...
#
#     user_screen_name                 user_created_at  user_followers_count  \
# day
# 0          nettexvii  Wed May 10 21:47:30 +0000 2017                    38
# 0           ZeRiMaRd  Thu Apr 30 08:45:39 +0000 2009                  3099
# 0         ritaschott  Sun Jul 24 20:53:09 +0000 2011                  3494
# 0           GAMMY_CT  Sat Aug 10 00:01:27 +0000 2019                     3
# 0          intensing  Sun Sep 18 01:43:51 +0000 2016                  3142
# ..               ...                             ...                   ...
# 6        TaoistRedux  Sun Jun 01 22:19:11 +0000 2014                   211
# 6          Maryjgeer  Wed Dec 26 04:58:13 +0000 2012                    59
# 6         HLoveshaft  Tue Jul 10 20:03:44 +0000 2018                   578
# 6          BRADvsALL  Mon Nov 04 03:40:46 +0000 2019                    76
# 6      RobotMythical  Fri Apr 17 01:30:16 +0000 2020                    68
#
#      user_friends_count  is_quote          user_id_str  user_verified  \
# day
# 0                    89         0   862423877200334848              0
# 0                   935         0             36624954              0
# 0                  4940         0            341713853              0
# 0                    78         0  1159978026953793536              0
# 0                  3146         0   777322209345843200              0
# ..                  ...       ...                  ...            ...
# 6                   216         0           2540388505              0
# 6                   159         0           1036338158              0
# 6                   892         0  1016774994876133376              0
# 6                   257         0  1191198511406211072              0
# 6                    91         0  1250959706262134784              0
#
#                                       user_description  \
# day
# 0                                currently in a corner
# 0    Mexican American. Gay. Obsessed With Batman. C...
# 0                                              #resist
# 0    Old Disabled RN. I try to limit my comments to...
# 0    Donna Marie's husband, Democrat, Vet, RN #Resi...
# ..                                                 ...
# 6    We should not have to dumb down America just t...
# 6    Wife,  mother,  grandmother of five beautiful ...
# 6    I'm like a cross between John Galt, Keyser Sze...
# 6    How embarrassing is it to #America that the ev...
# 6    theology and finance r cool| rollercoaster lov...
#
#                          user_name    neg    neu    pos  compound
# day
# 0                           nettex  0.000  0.846  0.154    0.7798
# 0                          Daniel   0.167  0.761  0.071   -0.6325
# 0                      rita schott  0.107  0.717  0.176    0.2732
# 0                            Cindy  0.000  1.000  0.000    0.0000
# 0               on_hiatus 2.0 (tm)  0.000  1.000  0.000    0.0000
# ..                             ...    ...    ...    ...       ...
# 6    Kyle Burns #BlackLivesMatter   0.000  0.734  0.266    0.4404
# 6                      Mary J Geer  0.122  0.878  0.000   -0.6800
# 6                   H.P. Loveshaft  0.329  0.671  0.000   -0.8949
# 6                             Brad  0.000  0.803  0.197    0.4019
# 6               white Kanye west    0.141  0.730  0.129   -0.0567
#
# [409139 rows x 15 columns]

# %%
df_t2=df_t.copy()
df_t2=df_t2[(abs(df_t2['compound'])>.025)]

df_b2=df_b.copy()
df_b2=df_b2[(abs(df_b2['compound'])>.025)]
df_b2
# Out:
#           created_at                                               text  \
# week day
# 36   1    2020-09-01  Anyone else notice that Trump supporters have ...
#      1    2020-09-01  Joe Biden has been trying to win the White Hou...
#      1    2020-09-01  Your dad is only 3 YEARS younger than Biden cu...
#      1    2020-09-01  The Trump campaign manipulated a video from @J...
#      1    2020-09-01  @JoyceWhiteVance @Acyn I transcribed Trump's i...
# ...              ...                                                ...
# 48   5    2020-11-28  AL GORE WON!   STACEY ABRAMS WON!   BIDEN WON!...
#      5    2020-11-28  @ScottyTamale @oldmadlady1 @realDonaldTrump RE...
#      5    2020-11-28  Yesterday I had to show a 21 year old a pic of...
#      5    2020-11-28  #Packers History: 9/13/2009    Aaron Rodgers t...
#      5    2020-11-28  Trump was in a frenzy to finalize his bird-kil...
#
#          user_screen_name                 user_created_at  \
# week day
# 36   1            cathymv  Mon Dec 08 16:00:12 +0000 2008
#      1          RobinWigg  Tue Jul 28 11:37:54 +0000 2009
#      1          SahilAgg4  Wed Apr 12 23:36:39 +0000 2017
#      1           padenpur  Tue Feb 17 21:10:18 +0000 2009
#      1    Itsagoodlife48G  Sun Aug 19 06:14:11 +0000 2012
# ...                   ...                             ...
# 48   5     nomalynneggers  Sun Nov 06 01:15:02 +0000 2011
#      5    Patricklemonade  Mon Nov 23 04:26:00 +0000 2020
#      5       bougiekommie  Sun Apr 07 00:49:13 +0000 2019
#      5      BookOfEli_NFL  Mon Jan 01 19:58:34 +0000 2018
#      5         greggo1685  Wed Jun 13 20:40:13 +0000 2012
#
#           user_followers_count  user_friends_count  is_quote  \
# week day
# 36   1                    6931                7519         0
#      1                   43300                1522         0
#      1                      28                 165         0
#      1                   48553               53122         0
#      1                   23649               25645         0
# ...                        ...                 ...       ...
# 48   5                    3734                3819         0
#      5                       1                  11         0
#      5                     710                1377         0
#      5                    5493                 878         0
#      5                    1128                1362         1
#
#                   user_id_str  user_verified  \
# week day
# 36   1               17965226              0
#      1               60880381              1
#      1     852304485535936512              0
#      1               21130829              0
#      1              767029620              0
# ...                       ...            ...
# 48   5              405940460              0
#      5    1330729261326594049              0
#      5    1114691563018498049              0
#      5     947920001448726528              0
#      5              607614048              0
#
#                                            user_description  \
# week day
# 36   1    Conservative NY'er- what can go wrong?NASCAR f...
#      1    Global finance correspondent for the Financial...
#      1    Progressive social democrat. I like films, Mar...
#      1    Rescue dog Mom! #Resist #DumpTrump #DitchMitch...
#      1    Unite for #Biden2020 #TrumpRussia #GOPComplici...
# ...                                                     ...
# 48   5    IM NOT POLITICALLY CORRECT IM A PROUD #DEPLORA...
#      5                     Bikini Bottom. I'm ALWAYS right.
#      5                                  just some thoughts
#      5    Creator and host of @AMAFantasy    Co-host on ...
#      5                                                   \N
#
#                              user_name    neg    neu    pos  compound
# week day
# 36   1    Cathymv - #MAGA #CULT45 #KAG  0.000  0.701  0.299    0.7964
#      1              Robin Wigglesworth  0.000  0.833  0.167    0.7184
#      1                           Sahil  0.071  0.812  0.118    0.2960
#      1     Denise P Rescue Dog Mom (@)  0.113  0.887  0.000   -0.4257
#      1     Lisa #BleedingHeartLiberal   0.116  0.884  0.000   -0.6289
# ...                                ...    ...    ...    ...       ...
# 48   5             PROUD AMERICAN LADY  0.000  0.492  0.508    0.9474
#      5                         Patrick  0.169  0.683  0.148   -0.2831
#      5                              BK  0.057  0.879  0.065    0.0772
#      5                   Eli Berkovits  0.000  0.933  0.067    0.1280
#      5                      G.Lombardi  0.064  0.891  0.045   -0.2003
#
# [1707852 rows x 15 columns]

# %%
mean_val_t=[]
mean_val_t_adj=[]
for week in range(36,49):

    temp=[]
    temp2=[]
    if week==36:
        for day in range(1,7):
            temp.append((df_t.loc[week,day]['compound'].mean(),day))
            temp2.append((df_t2.loc[week,day]['compound'].mean(),day))
            if day==6:
                mean_val_t.append(temp)
                mean_val_t_adj.append(temp2)
            
    elif week==48:
        for day in range(6):
            temp.append((df_t.loc[week,day]['compound'].mean(),day))
            temp2.append((df_t2.loc[week,day]['compound'].mean(),day))
            if day==5:
                mean_val_t.append(temp)
                mean_val_t_adj.append(temp2)
    else:
        for day in range(7):
            temp.append((df_t.loc[week,day]['compound'].mean(),day))
            temp2.append((df_t2.loc[week,day]['compound'].mean(),day))

            if day==6:
                mean_val_t.append(temp)
                mean_val_t_adj.append(temp2)

# %%
mean_val_b=[]
mean_val_b_adj=[]
for week in range(36,49):

    temp=[]
    temp2=[]
    if week==36:
        for day in range(1,7):
            temp.append((df_b.loc[week,day]['compound'].mean(),day))
            temp2.append((df_b2.loc[week,day]['compound'].mean(),day))
            if day==6:
                mean_val_b.append(temp)
                mean_val_b_adj.append(temp2)
            
    elif week==48:
        for day in range(6):
            temp.append((df_b.loc[week,day]['compound'].mean(),day))
            temp2.append((df_b2.loc[week,day]['compound'].mean(),day))
            if day==5:
                mean_val_b.append(temp)
                mean_val_b_adj.append(temp2)
    else:
        for day in range(7):
            temp.append((df_b.loc[week,day]['compound'].mean(),day))
            temp2.append((df_b2.loc[week,day]['compound'].mean(),day))

            if day==6:
                mean_val_b.append(temp)
                mean_val_b_adj.append(temp2)

# %%
"""vals=[]
days=[]


i=0
while i<len(mean_val):
    vals.extend([a for a,b in mean_val[i]])
    days.extend([b for a,b in mean_val[i]])
    i=i+1"""
# Out:
# 'vals=[]\ndays=[]\n\n\ni=0\nwhile i<len(mean_val):\n    vals.extend([a for a,b in mean_val[i]])\n    days.extend([b for a,b in mean_val[i]])\n    i=i+1'

# %%
color_list=['#ff0012','#ff3800','#fc5500','#f76c00','#ef8000','#e59400','#d8a500','#c9b600','#b7c600','#a2d500','#88e300','#63f100','#0bfe16']

# %%
fig, ax=plt.subplots(6,1,figsize=(13,20))
i=0

while i<len(mean_val_t):
    y,x=list(map(list, zip(*mean_val_t[i])))
    b,a=list(map(list,zip(*mean_val_t_adj[i])))
    ax[1].plot(a,b,label=f'week {36+i}',color=color_list[i],linewidth=2)
    ax[0].plot(x,y,label=f'week {36+i}',color=color_list[i],linewidth=2)
    
    β,α=list(map(list, zip(*mean_val_b[i])))
    d,c=list(map(list,zip(*mean_val_b_adj[i])))
    ax[3].plot(c,d,label=f'week {36+i}',color=color_list[i],linewidth=2)
    ax[2].plot(α,β,label=f'week {36+i}',color=color_list[i],linewidth=2)
    
    ax[4].plot(c,d,color='blue',label='biden')
    ax[4].plot(a,b,color='red')
    ax[5].plot(x,y,color='red')
    ax[5].plot(α,β,color='blue')
    i=i+1

ax[0].set_title('un-adjusted data - Trump')
ax[1].set_title('adjusted data - Trump')
ax[3].set_title('un-adjusted data - Biden')
ax[2].set_title('adjusted data - Biden')
ax[4].set_title('un-adjusted data - both')
ax[5].set_title('adjusted data - both')


ax[0].legend(loc='upper center', bbox_to_anchor=(1.1,1 ),
          ncol=1, fancybox=True, shadow=True)


plt.show()

# %%
"""
maybe graph pct change 
do biden's data
see how the candidates data change week to week, maybe do some time series math.

"""
# Out:
# "\nmaybe graph pct change \ndo biden's data\nsee how the candidates data change week to week, maybe do some time series math.\n\n"
