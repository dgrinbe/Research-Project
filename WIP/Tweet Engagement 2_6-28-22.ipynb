# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\\PC (2)\Desktop\David\Tweet Engagement.csv')

# %%
df
# Out:
#           created_at                                               text  \
# 0         2020-09-01  Anyone else notice that Trump supporters have ...
# 1         2020-09-01                       Where in the f*ck is he?????
# 2         2020-09-01   First #TheCorruptPartyOfTrump #LootingDecency...
# 3         2020-09-01  Political and cultural elites like this rarely...
# 4         2020-09-01  Can we take the gloves off and tell the truth?...
# ...              ...                                                ...
# 17568963  2020-11-28  So let me get this straight. Trump is asking s...
# 17568964  2020-11-28  Those in the GOP who arent supporting Presiden...
# 17568965  2020-11-28      President Trump @realDonaldTrump in disguise.
# 17568966  2020-11-28  Im starting to think Donald Trumps lawyers are...
# 17568967  2020-11-28  @CB618444 @realDonaldTrump If you are fully su...
#
#          user_screen_name                 user_created_at  favorite_count  \
# 0                 cathymv  Mon Dec 08 16:00:12 +0000 2008               0
# 1         RosannaDaniels9  Fri Aug 12 06:48:50 +0000 2016               0
# 2                waybeyon  Sat May 01 01:59:07 +0000 2010               0
# 3           lindalhrar148  Tue Nov 29 20:43:31 +0000 2011               0
# 4                byronesk  Tue Aug 16 21:17:49 +0000 2011               0
# ...                   ...                             ...             ...
# 17568963        northkats  Tue Nov 23 01:26:59 +0000 2010               0
# 17568964  HarryMo73815220  Wed Jul 12 15:15:51 +0000 2017               0
# 17568965           sccurl  Wed Apr 29 19:37:02 +0000 2009               0
# 17568966        GiannaJax  Mon Oct 18 22:38:47 +0000 2010               0
# 17568967  irishtravelerAZ  Thu Oct 15 23:12:15 +0000 2020               0
#
#           user_followers_count  user_friends_count  is_quote  retweeted  \
# 0                         6931                7519         0          0
# 1                         1451                2169         1          0
# 2                         2140                2004         1          0
# 3                           75                 174         1          0
# 4                         2907                5001         0          0
# ...                        ...                 ...       ...        ...
# 17568963                  1786                3021         0          0
# 17568964                    76                 427         0          0
# 17568965                   201                 219         1          0
# 17568966                  2193                5001         0          0
# 17568967                   381                1006         0          0
#
#           retweet_count          user_id_str  user_verified  \
# 0                     0             17965226              0
# 1                     0   763990608159531013              0
# 2                     0            138930681              0
# 3                     0            424486405              0
# 4                     0            356438982              0
# ...                 ...                  ...            ...
# 17568963              0            218701194              0
# 17568964              0   885155753878732800              0
# 17568965              0             36454368              0
# 17568966              0            204534066              0
# 17568967              0  1316879490694393857              0
#
#                                            user_description  \
# 0         Conservative NY'er- what can go wrong?NASCAR f...
# 1         This is the Land of the FREE and Home of the B...
# 2         Tweet together* help find & share our current ...
# 3         Political junkie. Unapologetically Pro Israel ...
# 4         Conspirator, schizophrenic, co-conspirator. Sc...
# ...                                                     ...
# 17568963                                                 \N
# 17568964                                                 \N
# 17568965                                           #NotABot
# 17568966  Happy person, passionate sports fan and Hoya l...
# 17568967  Christian evangelist pro-lifepatriot MAGAtrave...
#
#                              user_name lang  reply_count  quote_count
# 0         Cathymv - #MAGA #CULT45 #KAG   en            0            0
# 1                Rosanna  IFB Patriots   en            0            0
# 2                                wayne   en            0            0
# 3                         Linda L'HRAR   en            0            0
# 4                        John Stoddart   en            0            0
# ...                                ...  ...          ...          ...
# 17568963                       diane c   en            0            0
# 17568964                    Harry Moon   en            0            0
# 17568965                   Sarah Curl    en            0            0
# 17568966         Gianna Bader Ginsburg   en            0            0
# 17568967                      johnnieB   en            0            0
#
# [17568968 rows x 17 columns]

# %%
df.dropna(inplace=True)

# %%
df['created_at']=pd.to_datetime(df['created_at'])
df.set_index('created_at',inplace=True)
df.head(2)
# Out:
#                                                          text  \
# created_at
# 2020-09-01  Anyone else notice that Trump supporters have ...
# 2020-09-01                       Where in the f*ck is he?????
#
#            user_screen_name                 user_created_at  favorite_count  \
# created_at
# 2020-09-01          cathymv  Mon Dec 08 16:00:12 +0000 2008               0
# 2020-09-01  RosannaDaniels9  Fri Aug 12 06:48:50 +0000 2016               0
#
#             user_followers_count  user_friends_count  is_quote  retweeted  \
# created_at
# 2020-09-01                  6931                7519         0          0
# 2020-09-01                  1451                2169         1          0
#
#             retweet_count         user_id_str  user_verified  \
# created_at
# 2020-09-01              0            17965226              0
# 2020-09-01              0  763990608159531013              0
#
#                                              user_description  \
# created_at
# 2020-09-01  Conservative NY'er- what can go wrong?NASCAR f...
# 2020-09-01  This is the Land of the FREE and Home of the B...
#
#                                user_name lang  reply_count  quote_count
# created_at
# 2020-09-01  Cathymv - #MAGA #CULT45 #KAG   en            0            0
# 2020-09-01         Rosanna  IFB Patriots   en            0            0

# %%
trump = df['text'].str.contains("trump|don",case=False)
trump=df[trump]

# %%
biden = df['text'].str.contains("biden|joe",case=False)
biden=df[biden]

# %%
del(df)
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\BorisGrinberg\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
trump['neg'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])
print("Trump1/4")
# Out:
# Trump1/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\2294826189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['neg'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])

# %%
trump['neu'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])
print("Trump2/4")
# Out:
# Trump2/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\811116558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['neu'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])

# %%
trump['pos'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])
print("Trump 3/4")
# Out:
# Trump 3/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\654701282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['pos'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])

# %%
trump['compound'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['compound'])
print("Trump Sentiment Analysis Completed")
# Out:
# Trump Sentiment Analysis Completed
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\2697586337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['compound'] = trump['text'].apply(lambda x:analyzer.polarity_scores(x)['compound'])

# %%
biden['neg'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])
print("Biden 1/4")
# Out:
# Biden 1/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\2349000600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden['neg'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])

# %%
biden['neu'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])
print("Biden2/4")
# Out:
# Biden2/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\1970649360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden['neu'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])

# %%
biden['pos'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])
print("Biden 3/4")
# Out:
# Biden 3/4
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\4120869899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden['pos'] = biden['text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])

# %%
biden['compound'] =  biden['text'].apply(lambda x:analyzer.polarity_scores(x)['compound'])
print("Biden Sentiment Analysis Completed")
# Out:
# Biden Sentiment Analysis Completed
# C:\Users\BorisGrinberg\AppData\Local\Temp\ipykernel_29652\1567379037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden['compound'] =  biden['text'].apply(lambda x:analyzer.polarity_scores(x)['compound'])

# %%
trump.to_csv('trump engagement.csv',index=True)
biden.to_csv('biden engagement.csv',index=True)

# %%
trump
# Out:
#                                                          text  \
# created_at
# 2020-09-01  Anyone else notice that Trump supporters have ...
# 2020-09-01   First #TheCorruptPartyOfTrump #LootingDecency...
# 2020-09-01  Can we take the gloves off and tell the truth?...
# 2020-09-01  @Timcast @realDonaldTrump @DonaldJTrumpJr so n...
# 2020-09-01  Anatomy of a Trump smear:  Trump makes a false...
# ...                                                       ...
# 2020-11-28  So let me get this straight. Trump is asking s...
# 2020-11-28  Those in the GOP who arent supporting Presiden...
# 2020-11-28      President Trump @realDonaldTrump in disguise.
# 2020-11-28  Im starting to think Donald Trumps lawyers are...
# 2020-11-28  @CB618444 @realDonaldTrump If you are fully su...
#
#            user_screen_name                 user_created_at  favorite_count  \
# created_at
# 2020-09-01          cathymv  Mon Dec 08 16:00:12 +0000 2008               0
# 2020-09-01         waybeyon  Sat May 01 01:59:07 +0000 2010               0
# 2020-09-01         byronesk  Tue Aug 16 21:17:49 +0000 2011               0
# 2020-09-01   michaelosas346  Sat Sep 09 14:46:28 +0000 2017               0
# 2020-09-01        celephane  Thu Mar 03 09:22:09 +0000 2016               0
# ...                     ...                             ...             ...
# 2020-11-28        northkats  Tue Nov 23 01:26:59 +0000 2010               0
# 2020-11-28  HarryMo73815220  Wed Jul 12 15:15:51 +0000 2017               0
# 2020-11-28           sccurl  Wed Apr 29 19:37:02 +0000 2009               0
# 2020-11-28        GiannaJax  Mon Oct 18 22:38:47 +0000 2010               0
# 2020-11-28  irishtravelerAZ  Thu Oct 15 23:12:15 +0000 2020               0
#
#             user_followers_count  user_friends_count  is_quote  retweeted  \
# created_at
# 2020-09-01                  6931                7519         0          0
# 2020-09-01                  2140                2004         1          0
# 2020-09-01                  2907                5001         0          0
# 2020-09-01                   236                 803         1          0
# 2020-09-01                  1751                2226         0          0
# ...                          ...                 ...       ...        ...
# 2020-11-28                  1786                3021         0          0
# 2020-11-28                    76                 427         0          0
# 2020-11-28                   201                 219         1          0
# 2020-11-28                  2193                5001         0          0
# 2020-11-28                   381                1006         0          0
#
#             retweet_count          user_id_str  user_verified  \
# created_at
# 2020-09-01              0             17965226              0
# 2020-09-01              0            138930681              0
# 2020-09-01              0            356438982              0
# 2020-09-01              0   906529242120421376              0
# 2020-09-01              0   705322358890860545              0
# ...                   ...                  ...            ...
# 2020-11-28              0            218701194              0
# 2020-11-28              0   885155753878732800              0
# 2020-11-28              0             36454368              0
# 2020-11-28              0            204534066              0
# 2020-11-28              0  1316879490694393857              0
#
#                                              user_description  \
# created_at
# 2020-09-01  Conservative NY'er- what can go wrong?NASCAR f...
# 2020-09-01  Tweet together* help find & share our current ...
# 2020-09-01  Conspirator, schizophrenic, co-conspirator. Sc...
# 2020-09-01                                    BetterDaysAhead
# 2020-09-01  Actress, Musician & Songwriter, Court Clerk 8t...
# ...                                                       ...
# 2020-11-28                                                 \N
# 2020-11-28                                                 \N
# 2020-11-28                                           #NotABot
# 2020-11-28  Happy person, passionate sports fan and Hoya l...
# 2020-11-28  Christian evangelist pro-lifepatriot MAGAtrave...
#
#                                user_name lang  reply_count  quote_count  \
# created_at
# 2020-09-01  Cathymv - #MAGA #CULT45 #KAG   en            0            0
# 2020-09-01                         wayne   en            0            0
# 2020-09-01                 John Stoddart   en            0            0
# 2020-09-01                  Wendy fields   en            0            0
# 2020-09-01           Georgie.    #Resist   en            0            0
# ...                                  ...  ...          ...          ...
# 2020-11-28                       diane c   en            0            0
# 2020-11-28                    Harry Moon   en            0            0
# 2020-11-28                   Sarah Curl    en            0            0
# 2020-11-28         Gianna Bader Ginsburg   en            0            0
# 2020-11-28                      johnnieB   en            0            0
#
#               neg    neu    pos  compound
# created_at
# 2020-09-01  0.000  0.701  0.299    0.7964
# 2020-09-01  0.000  0.895  0.105    0.4019
# 2020-09-01  0.268  0.654  0.078   -0.9169
# 2020-09-01  0.000  1.000  0.000    0.0000
# 2020-09-01  0.216  0.734  0.050   -0.8225
# ...           ...    ...    ...       ...
# 2020-11-28  0.000  0.953  0.047    0.2789
# 2020-11-28  0.242  0.657  0.100   -0.6256
# 2020-11-28  0.333  0.667  0.000   -0.2500
# 2020-11-28  0.193  0.807  0.000   -0.3865
# 2020-11-28  0.000  0.802  0.198    0.6901
#
# [10395134 rows x 20 columns]
